# %% [markdown]
# <a href="https://colab.research.google.com/github/DiyaShah2753/ML/blob/main/lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import io
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
data = pd.read_csv(io.BytesIO(uploaded['BuyComputer.csv']))
data.drop(columns=['User ID',],axis = 1,inplace = True)
data.head()
# Out:
#      <input type="file" id="files-98986179-67fe-4a57-8c6e-8af461e1f529" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98986179-67fe-4a57-8c6e-8af461e1f529">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv(io.BytesIO(uploaded['BuyComputer.csv']))
# data.drop(columns=['Purchased',],axis=1,inplace=True)
# x = data.head()
# print(x)

dataset = pd.DataFrame(data)

# # y = data['Purchased']
# dataset.drop(columns=['Purchased',],axis=1,inplace=True)
#dataset.head()
y = dataset['Purchased']
print(y)

x = dataset.drop(columns=['Purchased','User ID',],axis=1)
print(x)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.6)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

print("X_train scalling")
print(X_train)

print("x_test scalling")
print(X_test)
# Out:
# X_train scalling
# [[ 1.31087698e+00  1.32762752e+00]
#  [ 9.37839508e-01 -1.12260104e+00]
#  [-2.74532261e-01  1.16926348e-01]
#  [ 1.91764573e-01 -2.28988273e-01]
#  [ 3.78283307e-01  1.15467021e+00]
#  [ 9.85052062e-02  1.45752567e-01]
#  [-1.02060720e+00 -2.86640709e-01]
#  [-1.11386656e+00 -9.49643733e-01]
#  [-9.27347829e-01 -3.73119365e-01]
#  [ 1.87043318e+00 -6.03729112e-01]
#  [-1.02060720e+00 -1.46851566e+00]
#  [-7.40829096e-01 -1.52616810e+00]
#  [ 1.77717381e+00  1.74578785e-01]
#  [ 9.85052062e-02  1.90415189e+00]
#  [-6.47569729e-01  1.44293240e+00]
#  [ 3.78283307e-01 -8.48571805e-02]
#  [ 1.31087698e+00 -8.63165078e-01]
#  [-1.11386656e+00 -1.52616810e+00]
#  [ 1.96369254e+00  4.34014751e-01]
#  [-6.47569729e-01 -5.60309621e-02]
#  [ 3.78283307e-01  6.35798280e-01]
#  [ 7.51320774e-01  1.74578785e-01]
#  [-2.74532261e-01 -6.90207767e-01]
#  [-5.54310362e-01  2.36537139e+00]
#  [-1.11386656e+00  3.47536096e-01]
#  [ 1.40413634e+00  1.03936534e+00]
# ...

# %%
import numpy as np
import random

y_pred = []
len_x = len(X_train[0])
w = []
b = 0.2
print(len_x)

entries = len(X_train[:,0])
entries

for weights in range(len_x):
  w.append(random.randint(0,200))
  print(w)

def sigmoid(w):
  return  1/(1 + np.exp(X_train))
print(sigmoid(w))
# Out:
# 2
# [193]
# [193, 30]
# [[0.21234013 0.20955207]
#  [0.28133696 0.75447086]
#  [0.56820523 0.47080167]
#  [0.45220523 0.55699822]
#  [0.40654101 0.23963708]
#  [0.47539359 0.46362623]
#  [0.73509086 0.57117352]
#  [0.75284926 0.72104352]
#  [0.71653691 0.59221251]
#  [0.13349161 0.646509  ]
#  [0.73509086 0.81283167]
#  [0.67717713 0.82144497]
#  [0.14465246 0.45646582]
#  [0.47539359 0.12963928]
#  [0.6564626  0.19109166]
#  [0.40654101 0.52120157]
#  [0.21234013 0.70332151]
#  [0.75284926 0.82144497]
#  [0.12306798 0.39316805]
#  [0.6564626  0.51400408]
#  [0.40654101 0.34619696]
#  [0.32053358 0.45646582]
#  [0.56820523 0.66601314]
#  [0.63513505 0.0858517 ]
#  [0.75284926 0.41398004]
#  [0.19716056 0.26127247]
#  [0.61326347 0.68496552]
#  [0.12306798 0.1030683 ]
#  [0.78589982 0.38631208]
#  [0.32053358 0.78991026]
#  [0.85404458 0.79465406]
#  [0.45220523 0.646509  ]
#  [0.86529013 0.61291881]
#  [0.45220523 0.42803235]
#  [0.32053358 0.40006638]
#  [0.54519453 0.62650461]
# ...
